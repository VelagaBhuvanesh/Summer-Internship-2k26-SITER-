# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",        # your own machine
    user="root",             # default admin user
    password="chinna12",  # the one you set during installation
    database="cablytics_staging"  # or cablytics_warehouse
)

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    port=3306,
    user="root",
    password="chinna12"
)
cursor = conn.cursor()
cursor.execute("SHOW DATABASES")
for db in cursor:
    print(db)
conn.close()
# Out:
# ('cablytics_staging',)
# ('cablytics_warehouse',)
# ('classicmodels',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)
